# %%
import sqlalchemy
from sqlalchemy import inspect

from bigbangGraphQL.config import CONFIG
from bigbangGraphQL.app import db
from bigbangGraphQL.api.models import Email

# %%
db.create_all()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pymysql/connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File /opt/homebrew/Cellar/python@3.10/3.10.5/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File /opt/homebrew/Cellar/python@3.10/3.10.5/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
# ...

# %% [raw]
# new_post = Email(
#     mimeVersion="1.0",
#     senderAdress="3GPP_TSG_SA_DRAFTS 3GPP_TSG_SA_DRAFTS@LIST.ETSI.ORG",
#     dateTime="2022-07-05 09:46:15+00:00",
#     replyTo="Shabnam Sultana shabnam.sultana@ERICSSON.COM",
#     messageID="MN2PR15MB355089C4F298EE2BE9CF4A328D540@MN2PR15",
#     subject="Test bigbang_test",
#     fromAdress="Shabnam Sultana shabnam.sultana@ERICSSON.COM",
#     inReplyTo="VI1PR10MB1663A4DF7309758B8FCA075483540@VI1PR10",
#     contentType="text/plain; charset='utf-8';",
#     commentsTo="'Walewski, Joachim' joachim.walewski@SIEMENS.COM",
#     archivedAt="<test2>",
# )
# db.session.add(new_post)
# db.session.commit()

# %%
Email.query.all()
# Email.query.delete()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pymysql/connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File /opt/homebrew/Cellar/python@3.10/3.10.5/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File /opt/homebrew/Cellar/python@3.10/3.10.5/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
# ...

# %%
file_path = "mysql+pymysql://root:AsS0%rteD@localhost:3306/bigbang_test"
engine = sqlalchemy.create_engine(file_path)
connection = engine.connect()

inspector = inspect(engine)

for table_name in inspector.get_table_names():
    print(table_name)
